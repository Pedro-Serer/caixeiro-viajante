# %% [markdown]
# # UNDIRECTED GRAPHS

# %% [markdown]
# - #### Graph 1: Large and dense undirected graph
#
# ![Large and dense undirected graph](https://pedroserer.com.br/graphs/graph1.png)

# %%
graph1 = [
    ['A', 1, {2, 3, 4, 8}],
    ['B', 2, {1, 5, 6}],
    ['C', 3, {1, 6, 7}],
    ['D', 4, {1, 5, 11}],
    ['E', 5, {2, 4, 9}],
    ['F', 6, {2, 3, 9, 10}],
    ['G', 7, {3, 8, 10}],
    ['H', 8, {1, 11}],
    ['I', 9, {5, 6, 11}],
    ['J', 10, {6, 7, 11}],
    ['K', 11, {4, 9, 10, 8}]
]

# %% [markdown]
# - #### Graph 2: Small undirected graph
#
# ![Small undirected graph](https://pedroserer.com.br/graphs/graph2.png)

# %%
graph2 = [
    ['A', 1, {2, 3, 5}],
    ['C', 2, {1}],
    ['B', 3, {1, 4}],
    ['E', 4, {3, 5}],
    ['D', 5, {1, 4}]
]

# %% [markdown]
# - #### Graph 3: Small cycled undirected graph
#
# ![Small cycled undirected graph](https://pedroserer.com.br/graphs/graph3.png)

# %%
graph3 = [
    ['A', 1, [3, 4]],
    ['D', 2, [3, 4]],
    ['B', 3, [1, 2, 6]],
    ['C', 4, [1, 2]],
    ['F', 5, [6, 7]],
    ['E', 6, [3, 5, 6]],
    ['G', 7, [5, 6]]
]

# %% [markdown]
# - #### Graph 4: Sparse undirected graph
#
# ![Sparse undirected graph](https://pedroserer.com.br/graphs/graph4.png)

# %%
graph4 = [
    ['Z', 1, {2}],
    ['A', 2, {4, 3}],
    ['B', 3, {5}],
    ['C', 4, {5, 6, 7, 3}],
    ['D', 5, {7}],
    ['E', 6, {7, 4}],
    ['F', 7, {6, 5}],
]

# %% [markdown]
# # DIRECTED GRAPHS

# %% [markdown]
# - #### Digraph 1: Simple directed cyclic
#
# ![Simple directed cyclic](https://pedroserer.com.br/graphs/digraph1.png)

# %%
digraph1 = [
    ['A', 1, [3]],
    ['B', 2, [3]],
    ['C', 3, [2]],
    ['D', 4, [1]]
]

# %% [markdown]
# - #### Digraph 2: Simple directed acyclic graph (DAG)
#
# ![Digraph 2: Simple directed acyclic graph (DAG)](https://pedroserer.com.br/graphs/digraph2.png)

# %%
digraph2 = [
    ['Z', 1, {2}],
    ['A', 2, {4}],
    ['B', 3, {5}],
    ['C', 4, {5, 6}],
    ['D', 5, {7}],
    ['E', 6, {7}],
    ['F', 7, {}],
]
